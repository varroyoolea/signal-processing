# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# sampling rate
sr = 2000
# sampling interval
ts = 1.0/sr
t = np.arange(0,1,ts)

señal = 3*np.sin(2*np.pi*1* t) + np.sin(2*np.pi*4*t) + 0.5*np.sin(2*np.pi*7*t)

plt.figure(figsize = (8, 6))
plt.plot(t, señal, 'r')
plt.ylabel('Amplitude')

plt.show()

# %%
#FFT

fs        = 2000
dt        = 1/fs
Nt        = len(señal)
Nf        = int(Nt/2)
dif        = fs/Nt
t         = dt*np.array([x for x in range(Nt)])
f         = dif*np.array([x for x in range(Nf)])

signalSpectrum = np.abs(np.fft.fft(señal))

plt.figure()
plt.plot(f,signalSpectrum[0:len(f)])
#plt.xlim(0,1000)
#plt.legend()
plt.xlabel("Frequency [Hz]")
plt.ylabel("Amplitude")
plt.show()

# %%
from numpy.fft import fft, ifft
x= señal
X = fft(x)
N = len(X)
n = np.arange(N)
T = N/sr
freq = n/T 

plt.figure(figsize = (12, 6))
plt.subplot(121)

plt.stem(freq, np.abs(X), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('FFT Amplitude |X(freq)|')
plt.xlim(0, 10)

plt.subplot(122)
plt.plot(t, ifft(X), 'r')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.tight_layout()
plt.show()
# Out:
# c:\Anaconda\lib\site-packages\numpy\core\_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
